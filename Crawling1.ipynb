# %%
import requests
from bs4 import BeautifulSoup
res = requests.get('http://v.media.daum.net/v/20170615203441266') #resurce
soup = BeautifulSoup(res.content, 'html.parser') #parser 비정형데이터
mydata = soup.find('title')
print(mydata.get_text())
# Out:
# 잔금대출에도 DTI 규제 적용 검토

# %%
res.content
# Out:
# b'<!doctype html>\n<html lang="ko"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <style>\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/page/3e96c93f90d4df7aca693bfb2ba2ea76d2d14d92.css\');\n            @import url(\'//t1.daumcdn.net/harmony_static/cloud/2021/05/03/common.4fa0ea63845693bada8b.css\')\n        </style> \n  <style>\n            /* \xeb\x8b\xa4\xec\x9d\x8c \xec\xb9\xb4\xed\x8e\x98 \xec\x86\x8c\xec\x85\x9c \xec\x89\x90\xec\x96\xb4 \xec\x9e\x84\xec\x8b\x9c \xeb\xb9\x84\xed\x99\x9c\xec\x84\xb1\xed\x99\x94 */\n            .list_sns li:nth-child(6) {\n                display: none;\n            }\n        </style> \n  <meta property="mccp:docId" content="nkhSoinQsa"> \n  <meta property="og:site_name" content="\xeb\x8b\xa4\xec\x9d\x8c\xeb\x89\xb4\xec\x8a\xa4"> \n  <meta property="og:title" content="\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xec\x97\x90\xeb\x8f\x84 DTI \xea\xb7\
# ...

# %%
from bs4 import BeautifulSoup
html =      "<html> \
                <body> \
                        <h1 id='title'>[1]크롤링이란?</h1> \
                        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p> \
                        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p> \
                </body> \
            </html>" # \ 역슬래시 대신에 ''' 써줘도 됨.
soup = BeautifulSoup(html, "html.parser")
# 태그로 검색 방법
data = soup.find('h1')
print(data)
print(data.string)
print(data.get_text())
# Out:
# <h1 id="title">[1]크롤링이란?</h1>
# [1]크롤링이란?
# [1]크롤링이란?

# %%
from bs4 import BeautifulSoup
html =      "<html> \
                <body> \
                        <h1 id='title'>[1]크롤링이란?</h1> \
                        <p class='cssstyle'>웹페이지에서 필요한 데이터를 추출하는 것</p> \
                        <p id='body' align='center'>파이썬을 중심으로 다양한 웹크롤링 기술 발달</p> \
                </body> \
            </html>" # \ 역슬래시 대신에 ''' 써줘도 됨.
soup = BeautifulSoup(html, "html.parser")
# 태그로 검색 방법
data1 = soup.find('p', class_ = 'cssstyle')
data2 = soup.find('p', 'cssstyle')
data3 = soup.find('p', attrs = {'align': 'center'})
data4 = soup.find(id = 'body')
print(data1)
print(data2)
print(data3)
print(data4)
# Out:
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>
# <p class="cssstyle">웹페이지에서 필요한 데이터를 추출하는 것</p>
# <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>
# <p align="center" id="body">파이썬을 중심으로 다양한 웹크롤링 기술 발달</p>

# %%
paragraph_data = soup.find_all('p')

for paragraph in paragraph_data:
    print(paragraph.get_text())
# Out:
# 웹페이지에서 필요한 데이터를 추출하는 것
# 파이썬을 중심으로 다양한 웹크롤링 기술 발달

# %%
import requests
from bs4 import BeautifulSoup

# 1) requests 라이브러리를 활용한 HTML 페이지 요청
# 1-1) res객체에 HTML 데이터가 저장되고, res.content로 데이터를 추출할 수 있음
res = requests.get('http://v.media.daum.net/v/20170615203441266')

# print(res.content)
# 2) HTML 페이지 파싱 BeautifulSoup(HTML 데이터, 파싱 방법)
# 2-1) BeautifulSoup 파싱방법
soup = BeautifulSoup(res.content, 'html.parser')

# 3) 필요한 데이터 검색
title = soup.find('h3', 'tit_view') # class_='tit_view'로 대체 가능함.

# 4) 필요한 데이터 추출하기
print(title.get_text())

# 연습하기
data = soup.find('span', 'num_date')
print(data.get_text())
data2 = soup.find('span', 'txt_info')
print(data2.get_text())
# Out:
# 잔금대출에도 DTI 규제 적용 검토
# 2017. 06. 15. 20:34
# 김동욱

# %%
# data = soup.find_all('span', 'num_date') findall로 넣으면 에러남.
#리스트 형식으로 바꿔주기

data = soup.find_all('span', 'txt_info')
for item in data:
    print(item.get_text())
# Out:
# 김동욱
# 입력 2017. 06. 15. 20:34
# 수정 2017. 06. 15. 21:31

# %%
data = soup.find_all('span', 'txt_info')
print(data[0].get_text())
# Out:
# 김동욱

# %%
data = soup.find('div','layer_util layer_summary')
print(data.get_text())
# Out:
# 금융당국이 급증하는 가계부채 증가세를 막기 위해 아파트 잔금대출에도 소득을 따져 대출한도를 정하는 총부채상환비율(DTI)을 적용하는 방안을 유력하게 검토하고 있다.
# 지금은 집값을 기준으로 대출한도를 매기는 주택담보인정비율(LTV) 규제만 적용돼 소득이 없어도 집값의 70%를 빌려 잔금을 치르는 게 가능하다.
# 앞으로 잔금대출에 DTI가 적용되면 소득이 없는 사람은 집값의 70% 대출 받는 게 어려워진다. 기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.

# %%
# find_all 사용하기
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content, 'html.parser')

titles = soup.find_all('li', 'course')
for title in titles:
    print(title.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content, 'html.parser')

section = soup.find('ul', id = 'hobby_course_list')
titles = section.find_all('li','course') # 리스트형식..?
for title in titles:
    print(title.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content, 'html.parser')

section = soup.find('ul', id = 'dev_course_list')
titles = section.find_all('li','course')
for title in titles:
    print(title.get_text())
# Out:
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test')
soup = BeautifulSoup(res.content, 'html.parser')

section = soup.find('ul', id = 'dev_course_list')
titles = section.find_all('li','course')
for index, title in enumerate(titles):
    print(str(index + 1) + '.', title.get_text().split('-')[1].split('[')[0].strip())
# Out:
# 1. 강사가 실제 사용하는 자동 프로그램 소개
# 2. 필요한 프로그램 설치 시연
# 3. 데이터를 엑셀 파일로 만들기
# 4. 엑셀 파일 이쁘게! 이쁘게!
# 5. 나대신 주기적으로 파이썬 프로그램 실행하기
# 6. 파이썬으로 슬랙(slack) 메신저에 글쓰기
# 7. 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# 8. 네이버 API 사용해서, 블로그에 글쓰기
# 9. 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기

# %%
# 연습해보기

import requests
from bs4 import BeautifulSoup

res = requests.get('https://blog.naver.com/PostView.nhn?blogId=tech-plus&logNo=222335242419&proxyReferer=https:%2F%2Fblog.naver.com%2Ftech-plus%2F222335242419')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.find('span','se-fs-fs16 se-ff- se-weight-unset se-style-unset')
print(data.get_text())
# Out:
# 유선 이어폰을 사용하던 시절 ‘선’은 애물단지였어요. 러닝을 하다 선 때문에 스텝이 꼬이는 일도, 선이 의자나 책상에 걸려 폰이 바닥에 떨어지는 일도 흔했죠. 선을 없앨 수도 없고;;; 나도 스마트폰도 안전을 보장하기 위해 결국 사용 반경을 ‘선’ 위주로 맞춰야만 했어요.

# %%
# Selector 사용하기
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('li') # ul>li해도 됨. body>li하면 안됨. >는 정확한 경로 필요.
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
# Selector 사용하기
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('h3')
for item in items:
    print (item.get_text())
# Out:
# 나만의 엣지있는 블로그 사이트 만들기 (취미로 익히는 IT)
# 파이썬과 데이터과학 첫걸음 (IT 기본기 익히기)

# %%
# Selector 사용하기
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('html body h1')
for item in items:
    print (item.get_text())
# Out:
# 잔재미코딩 크롤링 테스트 페이지 (커리큘럼)

# %%
# Selector 사용하기
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('.course') #클래스 이름을 넣을대는 .클래스이름
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개 [2]
# (초급) - 필요한 프로그램 설치 시연 [5]
# (초급) - 데이터를 엑셀 파일로 만들기 [9]
# (초급) -     엑셀 파일 이쁘게! 이쁘게! [8]
# (초급) -     나대신 주기적으로 파이썬 프로그램 실행하기 [7]
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기 [40]
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기 [12]
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기 [42]
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
# id이름으로 검색하기
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('#start')
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %%
# 태그.클래스이름1.클래스이름2
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('li.course.paid')
for item in items:
    print (item.get_text())
# Out:
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %%
# ul\id이름 li.class이름
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('ul#hobby_course_list li.course')
for item in items:
    print (item.get_text())
# Out:
# (왕초보) - 클래스 소개
# (왕초보) - 블로그 개발 필요한 준비물 준비하기
# (왕초보) - Github pages 설정해서 블로그 첫 페이지 만들어보기
# (왕초보) - 초간단 페이지 만들어보기
# (왕초보) - 이쁘게 테마 적용해보기
# (왕초보) - 마크다운 기초 이해하고, 실제 나만의 블로그 페이지 만들기
# (왕초보) - 다양한 마크다운 기법 익혀보며, 나만의 블로그 페이지 꾸며보기

# %%
# select_one 한개 리턴하기.
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/blog/crawl_test_css')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select_one('ul#dev_course_list > li.course.paid')
for item in items:
    print (item.get_text())
# Out:
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버 블로그/트위터에 홍보하기 [412]

# %% [markdown]
# # 네이버 쇼핑 크롤링하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.shopping.naver.com/best100v2/main.nhn')
soup = BeautifulSoup(res.content, 'html.parser')
# items = soup.select('a._popular_srch_lst_li')
items = soup.select('#popular_srch_lst > li > span.txt')
for item in items:
    print (item.get_text())

# popular_srch_lst > li.on > span.txt > a
# Out:
# 어버이날 용돈박스
# 면도기
# 카네이션
# 어버이날 선물
# 크록스 키즈
# 닌텐도 스위치
# 마스크
# 크록스
# 에어팟 프로
# 어버이날 카네이션

# %%
res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('#productListArea > ul > li >p >a')
for item in items:
    print (item.get_text())
# Out:
# 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 지오다노 여 TR 블레이저 솔리드 371501
# 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 나이키 기능성 드라이핏 반팔티 레전드 718...
# 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 아디다스 오버핏 데일리 바람막이 우븐소재...
# 지오다노 여 나일론 조거팬츠 411522
# 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 아노락 바람막이 후드집업 반바지 트레이닝...
# 지오다노 지오다노 여 레인코트 371513
# 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# SOUP 기본 린넨 자켓 SW5JK80
# 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 이경희 란제리 레이스 슬립 가운세트
# 나이키 스우시 반팔티 827021-100
# 리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# 아디다스 FW19 T19 트랙 트레이닝 팬츠 DW6...
# 나이키 NSW 클럽 크루 프렌치테리 맨투맨 남...
# 리스트 기본 자켓 자켓 TWWJKK62010
# 아디다스 3D 트레포일 트랙팬츠 GN3534
# ...

# %%
res = requests.get('https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001')
soup = BeautifulSoup(res.content, 'html.parser')
items = soup.select('#productListArea > ul > li >p >a')
for item in items:
    print (item.get_text())
# Out:
# 아디다스 알파바운스 슬라이드 슬리퍼 BA87...
# 크록스 바야밴드 클로그 205089-126
# 몽블랑 사토리얼 반지갑 6cc 113215
# 크록스 크록밴드 클로그 슬리퍼 샌들 크림 ...
# MLB 루키 볼캡 뉴욕양키스 32CP77011
# 나이키 팬텀 데이브레이크 써밋화이트 크림...
# 나이키 헤리티지 힙색 BA5750-010
# 나이키 헤리티지86 퓨추라 워시드캡 913011...
# 아디다스 알파바운스 슬라이드 B41720
# 크록스 라이트라이드 클로그 204592-4CC
# 컨버스 척테일러 1970S 하이 스니커즈화 16...
# 나이키 에어 포스 1 07 CW2288-111
# 헬렌카민스키 비앙카 HSSHE100110
# 나이키 데이브레이크 써밋화이트 CK2351-10...
# 디올 오블리크 새들 플랫 카드지갑
# 크록스 바야밴드 클로그 7가지 컬러 205089
# 나이키 헤리티지 86 퓨추라 워시드 캡 9130...
# 생로랑 YSL 모노그램 카드지갑 BOW01 1000 ...
# 나이키 우먼스 에어맥스 엑시스 러닝화 AA2...
# 나이키 국내매장판 데이브레이크 써밋화이트...
# 몽블랑 블랙 레더 스트랩 벨트 38157
# 나이키 운동화 우먼스 코트 레거시 뮬 DB39...
# 크록스 바야밴드 클로그 205089
# 지샥 지코스모 지얄오크 정품보증서 쇼핑백...
# 캉골 워시드 버킷햇 K4224HT
# 나이키 우먼스 레볼루션 5 BQ3207-002
# 나이키 에어 테일윈드79 487754-100
# 나이키 첼린저 OG 라이트본 런닝화 CW7645-...
# 나이키 에어맥스 엑시스 AA2146-100
# 뉴발란스 남녀공용 토앤토 NB X T T FLIPFL...
# 뉴발란스 NEW BALANCE 슬리퍼 unisex SD150...
# 머리끈 35종 세트 헤어밴드 헤어끈 머리고무...
# 아디다스 공용 알파바운스 슬라이드 슬리퍼...
# 컨버스 척 테일러 올스타 리프트 캔버스 56...
# ...

# %%
site_list = ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000', 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001', 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000002', 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000003' ]

for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content, 'html.parser')
    items = soup.select('#productListArea > ul > li > p > a')
    print(site)
    for item in items:
        print(item.get_text())
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
# 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 지오다노 여 TR 블레이저 솔리드 371501
# 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 나이키 기능성 드라이핏 반팔티 레전드 718...
# 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 아디다스 오버핏 데일리 바람막이 우븐소재...
# 지오다노 여 나일론 조거팬츠 411522
# 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 아노락 바람막이 후드집업 반바지 트레이닝...
# 지오다노 지오다노 여 레인코트 371513
# 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# SOUP 기본 린넨 자켓 SW5JK80
# 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 이경희 란제리 레이스 슬립 가운세트
# 나이키 스우시 반팔티 827021-100
# 리스트 아웃포켓 원버튼 여름 자켓 TWWJKK6...
# 아디다스 FW19 T19 트랙 트레이닝 팬츠 DW6...
# ...

# %%
site_list = ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000', 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000001', 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000002', 'https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000003' ]

for site in site_list:
    res = requests.get(site)
    soup = BeautifulSoup(res.content, 'html.parser')
    items = soup.select('#productListArea > ul > li > p > a')
    print(site)
    for index, item in enumerate(items):
        print(str(index +1) + '.',item.get_text())
# Out:
# https://search.shopping.naver.com/best100v2/detail.nhn?catId=50000000
# 1. 타미힐피거 반팔 티셔츠 남자 여자 면티 T3...
# 2. 캘빈클라인언더웨어 남성 모던코튼 6팩 드로...
# 3. 나이키 남성용 NSW 클럽 조거팬츠 BV2679
# 4. 타미힐피거 남녀공용 카라티 반팔티 피케 폴...
# 5. 스튜디오톰보이 테일러드 린넨자켓 9100212...
# 6. 지오다노 여 프렌치 테리 조거핏 팬츠 4115...
# 7. 나이키 SB 로고 드라이핏 반팔티 AR4209-01...
# 8. 아디다스 코어18 레인 자켓 바람막이 윈드브...
# 9. 써스데이아일랜드 프릴 반팔 소매 원피스 T...
# 10. 지오다노 여 TR 블레이저 솔리드 371501
# 11. 메종키츠네 여성 폭스 헤드 반팔 WH AW0010...
# 12. 나이키 기능성 드라이핏 반팔티 레전드 718...
# 13. 나이키 W 스우시 하이 라이즈 우븐 팬츠 CZ...
# 14. 나이키 클럽 트레이닝 조거팬츠 BV2671 063
# 15. 아디다스 오버핏 데일리 바람막이 우븐소재...
# 16. 지오다노 여 나일론 조거팬츠 411522
# 17. 메종키츠네 폭스헤드 패치 반팔티 AM00103K...
# 18. 아디다스 바람막이 오운더런 자켓 M OWN TH...
# 19. 캘빈클라인진 21S S 여성 슬림핏 기본로고 ...
# 20. 써스데이아일랜드 빈티지 페이즐리 원피스 ...
# 21. 아노락 바람막이 후드집업 반바지 트레이닝...
# 22. 지오다노 지오다노 여 레인코트 371513
# 23. 아디다스 M 삼선 윈드브레이커 GQ0600 GQ06...
# 24. 트리플에이 무지티 반팔티 무지 반팔티셔츠...
# 25. 캘빈클라인 남성 모노그램 엠브로 반팔티셔...
# 26. SOUP 기본 린넨 자켓 SW5JK80
# 27. 나이키 W 리펠 에센셜 GX 미드 라이즈 조거...
# 28. 이경희 란제리 레이스 슬립 가운세트
# ...

# %%
site_list = ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=5000000'+str(i)]
for i in range(0, 5):
    print(site_list.get_text())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-574f74a5b4eb> in <module>
# ----> 1 site_list = ['https://search.shopping.naver.com/best100v2/detail.nhn?catId=5000000'+str(i)]
#       2 for i in range(0, 5):
#       3     print(site_list.get_text())
#
# NameError: name 'i' is not defined

# %% [markdown]
# # 네이버 주식 크롤링

# %%
# 인기 검색 종목
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select("#popularItemList > li > a")

for item in data:
    print(item.get_text())
# Out:
# 삼성중공업
# HMM
# 삼성전자
# 박셀바이오
# 셀트리온
# SK이노베이션
# 카카오
# 금호석유
# SK하이닉스
# 텔레칩스

# %%
# 주요 해외지수 
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select("div.rgt > ul.lst_major > li")

for item in data:
    print("지수이름:", item.find('a').get_text(), "현재지수:", item.find('span').get_text(), item.find('em').get_text())
# Out:
# 지수이름: 다우산업 현재지수: 34,230.34 상승
# 지수이름:  나스닥 현재지수: 13,582.43 하락
# 지수이름:  홍콩H 현재지수: 10,721.87 하락
# 지수이름:  상해종합 현재지수: 3,446.86 하락
# 지수이름:  니케이225 현재지수: 29,337.71 상승

# %%
# 외국인 순매수
import requests
from bs4 import BeautifulSoup

res = requests.get('https://finance.naver.com/sise/')
soup = BeautifulSoup(res.content, 'html.parser')

# data = soup.select("#frgn_deal_tab_0 > tbody > tr")
data = soup.select("#frgn_deal_tab_0 > tbody > tr > td:nth-child(2) > a")


for item in data:
    print(item.get_text())

for item in data:
    print("지수이름:", item.find('a').get_text(), "순매수:", item.find('td').get_text(), item.find('em').get_text())

# %% [markdown]
# #### requests 라이브러리로 작성한 코드

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select('h4.card-text')
for item in data:
    print (item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이

# %%
# 지마켓 상품명 가져오기 내가한거

import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G01')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select('#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li > a')
for item in data:
    print (item.get_text())
# Out:
# [에잇세컨즈]최대20% 남녀 아울렛 베스트셀러 셔츠/원피스/팬츠 外
# 메이킹유 블라우스/원피스/니트/가디건
# [에잇세컨즈]최대20% 남녀 아울렛 봄 특가 셔츠/원피스/팬츠 外
# 요즘에/여름신상+10%할인/데님/슬랙스/팬츠/스판/3XL~
# 1+1+1 나시/끈나시/속바지/면/텐셀/ 특가 구성
# 데이데이 봄여름신상/블라우스/셔츠/원피스/팬츠
# 더다다 신상 빅사이즈 루즈핏/원피스/팬츠/레깅스
# 루나샵 봄~여름신상 티셔츠/원피스/빅사이즈
# [데일리앤]봄신상/루즈핏/빅사이즈/브이넥/레터링/롱티셔츠
# [게스]22% 추가할인 GUESS 여름신상 대전
# 루즈델리 봄신상 빅사이즈/롱원피스/투피스
# 시크루즈/홈웨어/원피스/SET/롱원피스/빅사이즈
# [르오트]린넨자켓/티셔츠/블라우스/팬츠 80종
# 프라이데이/여름신상/빅사이즈/루즈핏/원피스/롱티
# 수맘 봄 여름 신상입고 홈웨어 잠옷 세트
# [잠뱅이]22%중복쿠폰 잠뱅이 데님/캐주얼의류 SALE
# 스위트바니/봄신상 롱원피스티셔츠/맨투맨/반팔/롱티
# 시스터 봄신상 6900~ 빅사이즈 롱원피스/롱티/세트
# [블루레이스]블루레이스외 여름 Big sale
# [BYC]복수구매할인/여성 팬티/위생/노라인/보정/나시속바지
# 스웨덴세탁소 빅사이즈 봄여름NEW 원피스/데님/데일리
# 26~34 빅사이즈 남여면팬츠3종세트/데님/밴딩/티셔츠
# [마르조]마르조X오나라 스프링 앤 썸머페스티벌
# 성진 패션 원피스/팬츠/블라우스
# 패션라인 봄블라우스 원피스/자켓/빅사이즈/니트
# 여름신상 홈웨어 잠옷 사은품 증정
# 홈쇼핑히트 블라우스/원피스/가디건/티셔츠/무료배송
# 티메이 봄신상 블라우스 티셔츠 맨투맨
# 다온샵 /봄여름신상+10%/청바지/슬랙스/티셔츠/3XL
# 브리치x한미미 BEST T셔츠/맨투맨/스커트
# [게스](신세계본점)[GUESS] 21SS 남여 데일리 데님 기획전(NL1D0200 NL1D0300 NL1D0304 NL1D0605 NL1D0610 NL1...
# ...

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EB%B0%B1%EC%8B%A0')
soup = BeautifulSoup(res.content, 'html.parser')

data = soup.select('#sp_nws')
for item in data:
    print (item.get_text())

# %% [markdown]
# #### urllib 라이브러리로 작성한 코드

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

res = urlopen('https://davelee-fun.github.io/')
soup = BeautifulSoup(res, 'html.parser')

data = soup.select('h4.card-text')
for item in data:
    print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이

# %% [markdown]
# #### http response code(크롤링할 페이지가 없는 경우)

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('https://davelee-fun.github.io/xxx')
if res.status_code != 200:
    print('페이지 없음')
else:
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text())
# Out:
# 페이지 없음

# %% [markdown]
# #### 여러페이지 한번에 크롤링하기

# %%
import requests
from bs4 import BeautifulSoup

for page_num in range(10):
    if page_num == 0:
        res = requests.get('http://davelee-fun.github.io/')
    else:
        res = requests.get('http://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('h4.card-text')
    for item in data:
        print(item.get_text().strip())
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루
# 상품명: 네이쳐리빙 피아블 클래식 방수 매트리스커버, 그레이
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 베이지
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 프렌치불독
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키그레이
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 화이트
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트
# 상품명: 쿠팡 브랜드 - 코멧 홈 순면 매트리스커버, 차콜그레이
# ...

# %%
import requests
from bs4 import BeautifulSoup

send_response(code, message=None) 
for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101')
    else:
        res = requests.get('https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101#&date=%2000:00:00&page=' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('div a')
    for item in data:
        print(item.get_text().strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-228d7f869216> in <module>
#       2 from bs4 import BeautifulSoup
#       3
# ----> 4 send_response(code, message=None)
#       5 for page_num in range(10):
#       6     if page_num == 0:
#
# NameError: name 'send_response' is not defined

# %% [markdown]
# ## 크롤링해서 엑셀파일로 데이터 저장

# %%
import openpyxl

def write_excel_template(filename, sheetname, listdata):
    excel_file = openpyxl.Workbook()
    excel_sheet = excel_file.active
    excel_sheet.column_dimensions['A'].width = 100
    excel_sheet.column_dimensions['B'].width = 20
    
    excel_sheet.append(['랭킹','상품명','정상가','판매가','할인율'])
    
    if sheetname != '':
        excel_sheet.title = sheetname
        
    for item in listdata:
        excel_sheet.append(item)
    excel_file.save(filename)
    excel_file.close()

# %%
import requests
from bs4 import BeautifulSoup

product_lists = list()

for page_num in range(10):
    if page_num == 0:
        res = requests.get('https://davelee-fun.github.io/')
    else:
        res = requests.get('https://davelee-fun.github.io/page' + str(page_num +1))
    soup = BeautifulSoup(res.content, 'html.parser')
    
    data = soup.select('div.card')
    for item in data:
        product_name = item.select_one('div.card-body h4.card-text')
        product_date = item.select_one('div.wrapfooter span.post-date')
        product_info = [product_name.get_text().strip(), product_date.get_text()]
        product_lists.append(product_info)

# %%
write_excel_template('tmp.xlsx', '상품정보', product_lists)

# %%
excel_file = openpyxl.load_workbook('tmp.xlsx')

# %%
excel_file.sheetnames
# Out:
# ['상품정보']

# %%
excel_sheet = excel_file["상품정보"]

# %%
for item in excel_sheet.rows:
    print(item[0].value, item[1].value)
# Out:
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루 05 Jun 2020
# 상품명: 슈에뜨룸 선인장 리플 침구 세트, 베이지 05 Jun 2020
# 상품명: 선우랜드 레인보우 2단 문걸이용 옷걸이 _중형, 화이트, 상세페이지참조 05 Jun 2020
# 상품명: 보드래 헬로우 누빔 매트리스커버, 핑크 05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 차콜 05 Jun 2020
# 상품명: 피아블 클래식 방수 매트리스커버, 화이트 05 Jun 2020
# 상품명: 더자리 에코항균 마이크로 매트리스커버, 밀키차콜그레이 05 Jun 2020
# 상품명: 더자리 프레쉬 퓨어 매트리스 커버, 퓨어 차콜그레이 05 Jun 2020
# 상품명: 몽쉐어 알러스킨 항균 매트리스 커버, 카키그레이 05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 트윌 순면 100% 홑겹 매트리스커버, 그레이 05 Jun 2020
# 상품명: 패브릭아트 항균 마이크로 원단 매트리스 커버, 아이보리 05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 차콜 05 Jun 2020
# 상품명: WEMAX 다용도 문옷걸이, 화이트, 1개 05 Jun 2020
# 상품명: 타카타카 프리미엄 나노 화이바 누빔 매트리스 커버, 젠틀핑핑 05 Jun 2020
# 상품명: 보몽드 순면스퀘어 누빔매트커버, 다크그레이 05 Jun 2020
# 상품명: 보드래 국내산 순면 60수 누빔 매트리스커버, 그레이 05 Jun 2020
# 상품명: 보드래 퍼펙트 누빔 매트리스커버, 베이지핑크 05 Jun 2020
# 상품명: 쿠팡 브랜드 - 코멧 홈 40수 순면 누빔 매트리스커버, 챠콜 05 Jun 2020
# 상품명: 바숨 순면 누빔 침대 매트리스커버, 화이트 05 Jun 2020
# 상품명: 프랑떼 항균 방수 매트리스커버, 화이트 05 Jun 2020
# 상품명: 보몽드 순면스퀘어 솔리드 누빔매트커버, 다크블루 05 Jun 2020
# ...
